# %% [markdown]
# ---
# # Categorical Plot Exercise
# ---

# %%
# 実行
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Exercise_1 : Seabornのデータセット（'taxis'）をdfとして読み込んでください

# %%
df = sns.load_dataset('taxis')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df = sns.load_dataset('taxis')</code>
# </details>

# %%
# 実行して表示
df.shape
# Out:
# (6433, 14)

# %% [markdown]
# Exercise_2 : dfのカラム毎の欠損値の合計を表示してください

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.isnull().sum()</code>
# </details>

# %% [markdown]
# Exercise_3 : 'payment'カラムが欠損していないレコードをランダムに(sample()を利用して）５つ表示してください。　ヒント　レクチャーでは出てきませんでしたがisnull()ではなくnotnull()というメソッドもあります。

# %%
df[df['payment'].notnull()].sample(5, random_state=17)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 4290 2019-03-14 12:13:45 2019-03-14 12:18:23           1      0.40   5.0
# 4143 2019-03-27 16:34:08 2019-03-27 16:44:36           1      1.62   8.5
# 5403 2019-03-15 08:42:56 2019-03-15 08:47:27           1      0.64   5.0
# 1893 2019-03-12 15:56:30 2019-03-12 16:14:19           1      0.77  11.5
# 2220 2019-03-28 07:13:14 2019-03-28 07:23:00           5      2.12   9.5
#
#        tip  tolls  total   color      payment                pickup_zone  \
# 4290  1.65    0.0   9.95  yellow  credit card               West Village
# 4143  0.00    0.0  12.80  yellow         cash  Times Sq/Theatre District
# 5403  1.00    0.0   9.30  yellow  credit card      Upper East Side South
# 1893  0.00    0.0  14.80  yellow         cash              Midtown North
# 2220  0.00    0.0  12.80  yellow         cash      Upper West Side South
#
#                  dropoff_zone pickup_borough dropoff_borough
# 4290  Greenwich Village North      Manhattan       Manhattan
# 4143    Upper West Side South      Manhattan       Manhattan
# 5403          Lenox Hill East      Manhattan       Manhattan
# 1893             Midtown East      Manhattan       Manhattan
# 2220          Lenox Hill East      Manhattan       Manhattan

# %%
df[~(df['payment'].isnull())].sample(5, random_state=17)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 4290 2019-03-14 12:13:45 2019-03-14 12:18:23           1      0.40   5.0
# 4143 2019-03-27 16:34:08 2019-03-27 16:44:36           1      1.62   8.5
# 5403 2019-03-15 08:42:56 2019-03-15 08:47:27           1      0.64   5.0
# 1893 2019-03-12 15:56:30 2019-03-12 16:14:19           1      0.77  11.5
# 2220 2019-03-28 07:13:14 2019-03-28 07:23:00           5      2.12   9.5
#
#        tip  tolls  total   color      payment                pickup_zone  \
# 4290  1.65    0.0   9.95  yellow  credit card               West Village
# 4143  0.00    0.0  12.80  yellow         cash  Times Sq/Theatre District
# 5403  1.00    0.0   9.30  yellow  credit card      Upper East Side South
# 1893  0.00    0.0  14.80  yellow         cash              Midtown North
# 2220  0.00    0.0  12.80  yellow         cash      Upper West Side South
#
#                  dropoff_zone pickup_borough dropoff_borough
# 4290  Greenwich Village North      Manhattan       Manhattan
# 4143    Upper West Side South      Manhattan       Manhattan
# 5403          Lenox Hill East      Manhattan       Manhattan
# 1893             Midtown East      Manhattan       Manhattan
# 2220          Lenox Hill East      Manhattan       Manhattan

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df[df['payment'].notnull()].sample(5)</code>
# </details>

# %%
df[df['payment'].isnull()!=True].sample(5, random_state=17)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 4290 2019-03-14 12:13:45 2019-03-14 12:18:23           1      0.40   5.0
# 4143 2019-03-27 16:34:08 2019-03-27 16:44:36           1      1.62   8.5
# 5403 2019-03-15 08:42:56 2019-03-15 08:47:27           1      0.64   5.0
# 1893 2019-03-12 15:56:30 2019-03-12 16:14:19           1      0.77  11.5
# 2220 2019-03-28 07:13:14 2019-03-28 07:23:00           5      2.12   9.5
#
#        tip  tolls  total   color      payment                pickup_zone  \
# 4290  1.65    0.0   9.95  yellow  credit card               West Village
# 4143  0.00    0.0  12.80  yellow         cash  Times Sq/Theatre District
# 5403  1.00    0.0   9.30  yellow  credit card      Upper East Side South
# 1893  0.00    0.0  14.80  yellow         cash              Midtown North
# 2220  0.00    0.0  12.80  yellow         cash      Upper West Side South
#
#                  dropoff_zone pickup_borough dropoff_borough
# 4290  Greenwich Village North      Manhattan       Manhattan
# 4143    Upper West Side South      Manhattan       Manhattan
# 5403          Lenox Hill East      Manhattan       Manhattan
# 1893             Midtown East      Manhattan       Manhattan
# 2220          Lenox Hill East      Manhattan       Manhattan

# %% [markdown]
# Exercise_4 : 欠損値を持つレコードの先頭５つを表示してください

# %%
df[df.isnull().sum(axis=1) > 0].head()
# Out:
#                  pickup             dropoff  passengers  distance  fare  \
# 7   2019-03-22 12:47:13 2019-03-22 12:58:17           0       1.4   8.5
# 42  2019-03-30 23:59:14 2019-03-30 23:59:17           1       0.0  80.0
# 445 2019-03-19 06:57:14 2019-03-19 07:00:08           1       1.3   5.5
# 491 2019-03-07 07:11:33 2019-03-07 07:11:39           1       1.6   2.5
# 545 2019-03-27 11:03:43 2019-03-27 11:14:34           1       4.2  15.0
#
#        tip  tolls   total   color      payment        pickup_zone  \
# 7     0.00    0.0   11.80  yellow          NaN        Murray Hill
# 42   20.08    0.0  100.38  yellow  credit card                NaN
# 445   0.00    0.0    6.30  yellow          NaN        Boerum Hill
# 491   0.00    0.0    5.80  yellow          NaN        Murray Hill
# 545   0.00    0.0   15.80  yellow          NaN  LaGuardia Airport
#
#         dropoff_zone pickup_borough dropoff_borough
# 7           Flatiron      Manhattan       Manhattan
# 42               NaN            NaN             NaN
# 445  Columbia Street       Brooklyn        Brooklyn
# 491      Murray Hill      Manhattan       Manhattan
# 545     Forest Hills         Queens          Queens

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df[df.isnull().sum(axis=1) > 0].head()</code>
# </details>

# %% [markdown]
# Exercise_5 : 欠損値を持つレコードの合計数を表示してください

# %%
len(df[df.isnull().sum(axis=1)>0])
# Out:
# 92

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>len(df[df.isnull().sum(axis=1) > 0])</code>
# </details>

# %% [markdown]
# Exercise_6 : 欠損値を持つレコードをdfからすべて削除してください

# %%
df.dropna(axis=0, inplace=True)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df.dropna(axis=0, inplace=True)</code>
# </details>

# %%
# 実行して表示
df.shape
# (6341, 14)であればOK
# Out:
# (6341, 14)

# %% [markdown]
# Exercise_7 : dfのカラムのうちデータタイプがfloat'型のものを抽出しdf_numericとしてください

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %%
df_numeric = df.select_dtypes('float')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df_numeric = df.select_dtypes('float')</code>
# </details>

# %%
# 実行して表示
df_numeric
# Out:
#       distance  fare   tip  tolls  total
# 0         1.60   7.0  2.15    0.0  12.95
# 1         0.79   5.0  0.00    0.0   9.30
# 2         1.37   7.5  2.36    0.0  14.16
# 3         7.70  27.0  6.15    0.0  36.95
# 4         2.16   9.0  1.10    0.0  13.40
# ...        ...   ...   ...    ...    ...
# 6428      0.75   4.5  1.06    0.0   6.36
# 6429     18.74  58.0  0.00    0.0  58.80
# 6430      4.14  16.0  0.00    0.0  17.30
# 6431      1.12   6.0  0.00    0.0   6.80
# 6432      3.85  15.0  3.36    0.0  20.16
#
# [6341 rows x 5 columns]

# %% [markdown]
# Exercise_8 : df_numericの相関係数（相関行列）を表示してください

# %%
df_numeric.corr()
# Out:
#           distance      fare       tip     tolls     total
# distance  1.000000  0.947958  0.476980  0.642333  0.929224
# fare      0.947958  1.000000  0.487101  0.617182  0.972311
# tip       0.476980  0.487101  1.000000  0.414670  0.650677
# tolls     0.642333  0.617182  0.414670  1.000000  0.690879
# total     0.929224  0.972311  0.650677  0.690879  1.000000

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df_numeric.corr()</code>
# </details>

# %% [markdown]
# Exercise_9 : 上記の相関行列をヒートマップとして表示してください。その際には横縦を6インチ、 4インチとして、相関係数の表示(annot=True)、cmap='coolwarm'の指定も行ってください(詳しくは別のセクションで説明します)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', vmax=1, vmin=-1, center=0);

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')</code>
# </details>

# %% [markdown]
# Exercise_10 : レクチャーで保存した'titanic_for_seaborn.csv'(index=Falseで保存)をdfとして読み込んでください。

# %%
df = pd.read_csv('titanic_non_null.csv')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>df = pd.read_csv('titanic_for_seaborn.csv')</code>
# </details>

# %%
# 実行して表示
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man

# %% [markdown]
# Exercise_11 : Seabornのテーマ設定を行ってください。(テキストのサイズは'talk'、スタイルは'darkgrid'、フォントは'Meiryo')

# %%
sns.set_theme(context='talk', style='darkgrid')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.set_theme(context='talk', style='darkgrid', font='Meiryo')</code>
# </details>

# %% [markdown]
# Exercise_12 : dfにおいて'sex'別の'fare'をストリッププロットで表示してください

# %%
import japanize_matplotlib

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(data=df, x='sex', y='fare')
plt.title('"sex"別の"fare"のストリッププロット')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.stripplot(data=df, x='sex', y='fare')</code>
# </details>

# %% [markdown]
# Exercise_13 : 同様のストリッププロットで、'embarked'による色分けを行ってください。その際には三種類の'embarked'のプロットを混在させずに独立して表示し、パレットを'prism'としてください。

# %%
plt.figure(figsize=(10, 5))
sns.stripplot(data=df, x='sex', y='fare', hue='embarked', dodge=True)
plt.title('"sex"別の"fare"のストリッププロット')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.stripplot(data=df, x='sex', y='fare', hue='embarked', dodge=True, palette='prism')</code>
# </details>

# %% [markdown]
# Exercise_14 : 'embarked'別のレコードの数をカウントプロットで表示してください(カラーパレットは'Set1')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='embarked', palette='Set1')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.countplot(data=df, x='embarked', palette='Set1')</code>
# </details>

# %% [markdown]
# Exercise_15 : 上記のカウントプロットを性別ごとに色分けしてください（カラーパレットは'Set2'）

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='embarked', hue='sex', palette='Set2')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.countplot(data=df, x='embarked', palette='Set2', hue='sex')</code>
# </details>

# %% [markdown]
# Exercise_16 : 性別で分けた年齢の平均値を、出航地別に色分けしてバープロットで表示してください（カラーパレット'hsv'）。さらにレジェンドの位置を「下寄りの中央」にし、そのタイトルを'embarked'にしてください

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='sex', y='age', hue='embarked', palette='hsv')
plt.legend(loc='lower center')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.barplot(data=df, x='sex', y='age', palette='hsv', hue='embarked', estimator=np.median)</code>
#     <code>plt.legend(loc="lower center", title='embarked')</code>
# </details>

# %% [markdown]
# Exercise_17 : 'who'別の'fare'をボックスプロットで表示してください。その際にカラーパレットを'Set3’、ボックスの幅を0.5に指定してください

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='who', y='fare', palette='Set3')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.boxplot(data=df, x='who', y='fare', palette='Set3', width=0.5)</code>
# </details>

# %% [markdown]
# Exercise_18 : 上記では大きな外れ値があるため比較が困難です。外れ値を非表示として、あらためてボックスプロットを表示してください

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='who', y='fare', palette='Set3', whis=100)
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.boxplot(data=df, x='who', y='fare', palette='Set3', width=0.5, sym="")</code>
# </details>

# %% [markdown]
# Exercise_19 : 'who'別の'age'をバイオリンプロットで表示してください。その際にカラーパレットは'spring'、色分けを'survived'で行い、さらにバイオリンの左右に分けて表示してください。

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='who', y='age', hue='survived', split=True, palette='spring')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.violinplot(data=df, x='who', y='age', palette='spring', hue='survived', split=True)</code>
# </details>

# %% [markdown]
# Exercise_20 : 性別ごとの年齢を'survived'で色分けし、また、プロットを混在させず分離してスウォームプロットで表示してください。（カラーパレットは'prism'）さらに、x軸ラベルを"男性"、"女性"にしてください

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(data=df, x='sex', y='age', hue='survived', dodge=True, palette='prism')
plt.xticks(['male', 'female'], ['男性', '女性'])
plt.legend(loc="upper center", title='Survived')
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.swarmplot(data=df, x='sex', y='age', hue='survived', palette='prism', dodge=True)</code>
#     <code>plt.xticks([0, 1] ,['男性', '女性'])</code>
# </details>

# %% [markdown]
# Exercise_21 : 生存・死亡をX軸にして、年齢をスウォームプロットで表示してください。ただし、2行3列のグリッド表示とし、行では'sex'での分類、列では'pclass'の分類となるようにしてください。さらにheightを4とし、それに対するwidthの比率を1.5としてください。　ヒント　catplot, row, col

# %%
sns.catplot(data=df, x='survived', y='age', kind='swarm', row='sex', col='pclass', height=4, aspect=1.5)
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.catplot(data=df, x='survived', y='age', height=4, aspect=1.5, row='sex', col='pclass', kind='swarm')</code>
# </details>

# %% [markdown]
# ## 以上
