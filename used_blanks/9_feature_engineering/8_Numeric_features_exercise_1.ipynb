# %% [markdown]
# ---
# #  8.Numerical Features Exercise
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(context='talk', style='darkgrid')

# %% [markdown]
# Exercise_1 : 3つのスケーラー（MaxAbsScalerを除く）をインポートしてください

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>from sklearn.preprocessing import StandardScaler</code><br>
#     <code>from sklearn.preprocessing import MinMaxScaler</code><br>
#     <code>from sklearn.preprocessing import RobustScaler</code><br>
# </details>

# %% [markdown]
# Exercise_2 : それぞれをインスタンス化してください

# %%
st_scaler = StandardScaler()
mm_scaler = MinMaxScaler()
ro_scaler = RobustScaler()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>st_scaler = StandardScaler()</code><br>
#     <code>mm_scaler = MinMaxScaler()</code><br>
#     <code>ro_scaler = RobustScaler()</code><br>
# </details>

# %%
# 実行して表示
# 外れ値を持つデータの作成
np.random.seed(17)
x1 = np.random.randn(100) * 10   # 標準偏差10、平均0
x2 = np.random.randint(-100, 100, 10)   # 10個の整数
X = np.concatenate([x1, x2]) - 10   # 全体を-10ずらす
X.min(), X.max()
# Out:
# (-106.0, 74.0)

# %%
len(X)
# Out:
# 110

# %%
X.shape
# Out:
# (110,)

# %% [markdown]
# Exercise_3 : Xの分布をヒストプロットで表示してください

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x=X, bins=12, kde=True, shrink=0.9)
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.histplot(X)</code><br>
# </details>

# %% [markdown]
# Exercise_4 : 以下を実行し、ERRORの最終行を参考にして、Xをスケーラーのパラメーターに適した形状に変更してください(X_reshaped)

# %%
# 実行して表示
X_st = st_scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 実行して表示
# ----> 2 X_st = st_scaler.fit_transform(X)
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:878, in StandardScaler.fit(self, X, y, sample_weight)
#     876 # Reset internal state before fitting
#     877 self._reset()
# --> 878 return self.partial_fit(X, y, sample_weight)
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:914, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     882 """Online computation of mean and std on X for later scaling.
#     883
#     884 All of X is processed as a single batch. This is intended for cases
#    (...)
#     911     Fitted scaler.
#     912 """
#     913 first_call = not hasattr(self, "n_samples_seen_")
# --> 914 X = self._validate_data(
#     915     X,
#     916     accept_sparse=("csr", "csc"),
#     917     dtype=FLOAT_DTYPES,
#     918     force_all_finite="allow-nan",
#     919     reset=first_call,
#     920 )
#     921 n_features = X.shape[1]
#     923 if sample_weight is not None:
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File /opt/anaconda3/envs/python_ml/lib/python3.9/site-packages/sklearn/utils/validation.py:1050, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043         else:
#    1044             msg = (
#    1045                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1046                 "Reshape your data either using array.reshape(-1, 1) if "
#    1047                 "your data has a single feature or array.reshape(1, -1) "
#    1048                 "if it contains a single sample."
#    1049             )
# -> 1050         raise ValueError(msg)
#    1052 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1053     raise ValueError(
#    1054         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1055         "Convert your data to numeric values explicitly instead."
#    1056     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-7.23734110e+00 -2.85462808e+01 -3.76098889e+00  1.45311290e+00
#   3.71904682e-01  8.86638930e+00 -1.11169829e+01 -1.36210134e+01
#  -8.51324955e+00 -1.43778315e+01  1.17125700e+01  1.52310251e+00
#  -2.81881234e+01 -1.13804934e+01 -4.60160386e+00 -2.77528229e+01
#   3.14876536e+00 -1.47344805e+01 -2.09222990e+01 -1.25002744e+01
#  -1.98229430e+01  3.12690925e-01 -5.08666224e+00 -1.44664660e+01
#  -1.80636008e+01 -8.68732242e+00 -2.21256024e+01 -8.40009147e+00
#  -1.75522304e+01 -6.50104008e+00 -2.24582357e-01 -1.13858525e+01
#  -8.96143695e+00 -6.99408964e+00 -3.17947044e-01 -1.30376158e+00
#  -4.32216911e+00 -5.34717656e+00 -2.16537308e+01 -3.03599479e+01
#  -2.15541329e+01  2.34515739e+01 -8.73272789e+00 -1.69417890e+01
#  -4.42325569e+00 -9.00853400e+00 -3.62073826e+00 -2.96889319e+00
#  -1.91609315e+01 -1.78601423e+01  1.19181796e+00 -1.98339611e+01
#  -7.55479979e+00 -1.58140974e+01 -5.70436098e+00 -2.01598012e+00
#  -1.61007005e+01  1.85404207e+00 -1.71083401e+01 -1.78112893e+01
#  -1.23037298e+01 -8.79804917e+00 -1.78846984e+01 -3.96012262e+01
#  -1.79558112e+01 -7.15417750e+00 -4.77462718e+00 -9.16445556e+00
#   1.72079559e+01 -3.88992117e+00 -1.83594400e+01 -1.00369604e+01
#  -6.06905320e+00 -3.15504916e+00 -2.24798317e+00 -4.43997114e+00
#  -1.54097990e+01  5.24417248e+00  2.08385131e+00 -9.48722716e+00
#  -1.42663121e+01 -1.92059772e+00 -9.42720238e+00 -2.04017157e+01
#  -6.58519143e-01 -1.12003454e+01  1.20701631e+01 -4.39993078e+01
#   2.33528896e+00 -1.58788084e+01 -1.97693692e+01 -5.31929700e+00
#   1.87112692e+01 -2.20808568e+01  3.60318015e-02  1.30726446e+00
#  -4.39960308e+00 -1.61839730e+01 -1.22479872e+01  1.21590145e+01
#   7.00000000e+01  1.30000000e+01 -1.06000000e+02  6.50000000e+01
#  -7.60000000e+01 -2.30000000e+01  7.40000000e+01 -8.60000000e+01
#  -5.90000000e+01 -3.60000000e+01].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
X_reshaped = X.reshape(-1, 1)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>X_reshaped = X.reshape(-1, 1)</code><br>
# </details>

# %%
# 実行して表示
X_reshaped[:5]
# Out:
# array([[ -7.2373411 ],
#        [-28.54628079],
#        [ -3.76098889],
#        [  1.4531129 ],
#        [  0.37190468]])

# %% [markdown]
# Exercise_5 : st_scalerでX_reshapedのスケーリングを行ってください

# %%
X_st = st_scaler.fit_transform(X_reshaped)

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>X_st = st_scaler.fit_transform(X_reshaped)</code><br>
# </details>

# %%
# 実行して表示
X_st[:5]
# Out:
# array([[ 0.10435842],
#        [-0.84974033],
#        [ 0.26001062],
#        [ 0.49346982],
#        [ 0.44505918]])

# %%
# 実行して表示
X_st.std(), X_st.mean()
# ほぼ1、ほぼ0
# Out:
# (1.0, -6.0557619525008536e-18)

# %% [markdown]
# Exercise_6: X_stを1次元に戻し、スケールされた値の分布をヒストプロットで確認してください

# %%
# 実行して表示
X_st.ndim
# Out:
# 2

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x=X_st.flatten(), bins=12, kde=True)
plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>sns.histplot(X_st.flatten())</code>
# </details>

# %% [markdown]
# Exercise_7: それぞれのスケーラーでXをスケーリングし、ヒストプロットで結果を表示してください

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 4), tight_layout=True)

sns.histplot(x=X, kde=True, ax=axes[0])
sns.histplot(x=st_scaler.fit_transform(X_reshaped).flatten()  , kde=True, ax=axes[1])   # x= 以降を埋める
axes[1].set_title('Standerd')
sns.histplot(x=mm_scaler.fit_transform(X_reshaped).flatten()  , kde=True, ax=axes[2])   # x= 以降を埋める
axes[2].set_title('MinMax')
sns.histplot(x=ro_scaler.fit_transform(X_reshaped).flatten()  , kde=True, ax=axes[3])   # x= 以降を埋める
axes[3].set_title('Robust')
plt.show()

# binsの設定によりRobustScalerでスケーリングしたヒストプロットは多少形が異ってしまうことがあります。

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>x=st_scaler.fit_transform(X.reshape(-1, 1)).flatten()</code><br>
#     <code>x=mm_scaler.fit_transform(X.reshape(-1, 1)).flatten()</code><br>
#     <code>x=ro_scaler.fit_transform(X.reshape(-1, 1)).flatten()</code>
# </details>

# %% [markdown]
# 以下のセルを実行してボストン住宅価格データセットに関するデータフレームを作成してください。
# ※ 以降において動画と異なる部分がございます。あらかじめご了承のほど何卒よろしくお願いいたします。

# %%
# 実行して表示
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack((raw_df.values[::2, :], raw_df.values[1::2, :3]))

feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'target']
df = pd.DataFrame(data, columns=feature_names)

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# Exercise_8: ふたつのトランスフォーマーをインポートしてください

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>from sklearn.preprocessing import QuantileTransformer</code><br>
#     <code>from sklearn.preprocessing import PowerTransformer</code>
# </details>

# %% [markdown]
# Exercise_9 : それぞれのインスタンスを作成して下さい。QuantileTransformerに関しては、'normal'と'uniform'のふたつを作成し、n_quantiles=506としてください。その他はデフォルトの設定でかまいません

# %%
qut_n = QuantileTransformer(output_distribution='normal', n_quantiles=506)
qut_u = QuantileTransformer(output_distribution='uniform', n_quantiles=506)
pot = PowerTransformer()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>qut_n = QuantileTransformer(output_distribution='normal', n_quantiles=506)</code><br>
#     <code>qut_u = QuantileTransformer(output_distribution='uniform', n_quantiles=506)</code><br>
#     <code>pot = PowerTransformer()</code>
# </details>

# %%
# 実行
# 特徴量を3つに絞って考える
df_t = df[['RM', 'AGE', 'LSTAT']]

# %%
# 実行して表示
fig, axes = plt.subplots(1, 3, figsize=(14, 4), tight_layout=True)
sns.histplot(df['INDUS'], ax=axes[0])
sns.histplot(df['AGE'], ax=axes[1])
sns.histplot(df['LSTAT'], ax=axes[2])
plt.show()

# %% [markdown]
# Exercise_10 : 関数plotsを完成させ、df_tのそれぞれの特徴量の非線形変換の結果をヒストプロットで表示してください

# %%
def plots(feature):
    fig, axes = plt.subplots(1, 4, figsize=(14, 4), tight_layout=True)
    sns.histplot(x=df[feature] , ax=axes[0])
    axes[0].set_title(feature)
    sns.histplot(x=qut_u.fit_transform(df[[feature]]).flatten(), ax=axes[1])   # x= 以降を埋める
    axes[1].set_title('Quantile Uniform')
    sns.histplot(x=qut_n.fit_transform(df[[feature]]).flatten(), ax=axes[2])   # x= 以降を埋める
    axes[2].set_title('Quantile Normal')
    sns.histplot(x=pot.fit_transform(df[[feature]]).flatten(), ax=axes[3])   # x= 以降を埋める
    axes[3].set_title('Power')
    plt.show()

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>x=qut_u.fit_transform(df[[feature]]).flatten()</code><br>
#     <code>x=qut_n.fit_transform(df[[feature]]).flatten()</code><br>
#     <code>x=pot.fit_transform(df[[feature]]).flatten()</code>
# </details>

# %%
# 実行して表示
for feature in df_t.columns:
    plots(feature)

# %% [markdown]
# Exercise_11 : KBinsDiscretizerをインポートし、インスタンスを作成してください。その際にビンの数を3とし、'uniform'、'ordinal'を設定してください。

# %%
# インポート
from sklearn.preprocessing import KBinsDiscretizer

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>from sklearn.preprocessing import KBinsDiscretizer</code>
# </details>

# %%
discretizer = KBinsDiscretizer(n_bins=3, strategy='uniform', encode='ordinal')

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>discretizer = KBinsDiscretizer(strategy='uniform', encode='ordinal')</code>
# </details>

# %%
# 実行して表示
y = df[['target']][:12]   # 12のサンプルに絞って考える。yはデータフレーム
y[:5]
# Out:
#    target
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2

# %% [markdown]
# Exercise_12 : discretizerを用いて、yを離散化（ビニング）した結果を表示てください

# %%
discretizer.fit_transform(y)
# Out:
# array([[1.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>discretizer.fit_transform(y)</code>
# </details>

# %% [markdown]
# Exercise_13 : 上記のdiscretizerのstrategyを'quantile'に変更した新規インスタンス作成し、同様にyを離散化してください。
# ※　前回の結果との違いを確認してください

# %%
discretizer = KBinsDiscretizer(n_bins=3, strategy='quantile', encode='ordinal')

# %%
discretizer.fit_transform(y)
# Out:
# array([[1.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>discretizer = KBinsDiscretizer(n_bins=3, strategy='quantile', encode='ordinal')</code><br>
#     <code>discretizer.fit_transform(y)</code>
# </details>

# %% [markdown]
# Exercise_14 :  Pandasのcutを用いて、yを数値の25以下のグループ('group_A')、25より大きいグループ('group_B')に分けたラベルのリストを表示して下さい

# %%
# 実行して表示
y.min(), y.max()
# Out:
# (target    15.0
#  dtype: float64,
#  target    36.2
#  dtype: float64)

# %%
y.ndim
# Out:
# 2

# %%
y['target'].ndim
# Out:
# 1

# %%
# classes = pd.cut(
# 				x.flatten(),
# 				bins=[3.560, 5.837, 6.086, 6.376, 6.75 , 8.78 ],
# 				labels=['very low', 'low', 'medium', 'high', 'very hight']
# )
# classes
# # rightを含み、leftを含まない

# %%
# pd.cut()の第一引数には1次元のndarrayかlistを指定しなければならないことに注意
# yはデータフレームのため、ndarrayにしてから平坦化を行う
groups = pd.cut(y['target'], bins=[14.9, 25, 36.2], labels=['group_A', 'group_B'] )

# %% [markdown]
# <details>
#     <summary><font color='red'>解答はここをクリック</font></summary>
#     <code>groups = pd.cut(y.values.flatten(), bins=[14, 25, 36.2], labels=['group_A', 'group_B'])</code><br>
#     <code>※15より小さい値を設定すればよい</code>
# </details>

# %%
# 実行して表示
groups
# Out:
# 0     group_A
# 1     group_A
# 2     group_B
# 3     group_B
# 4     group_B
# 5     group_B
# 6     group_A
# 7     group_B
# 8     group_A
# 9     group_A
# 10    group_A
# 11    group_A
# Name: target, dtype: category
# Categories (2, object): ['group_A' < 'group_B']

# %% [markdown]
# ## 以上
